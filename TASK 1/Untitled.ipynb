# %% [markdown]
# CROPPING IMAGE

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('abc.jpeg')

# %%
print(img)
# Out:
# [[[ 17 140 207]
#   [ 17 140 207]
#   [ 17 140 207]
#   ...
#   [179 222 231]
#   [181 224 233]
#   [180 224 235]]
#
#  [[ 17 140 207]
#   [ 17 140 207]
#   [ 17 140 207]
#   ...
#   [181 224 233]
#   [181 224 233]
#   [180 224 235]]
#
#  [[ 17 140 207]
#   [ 17 140 207]
#   [ 16 139 206]
#   ...
#   [182 226 235]
#   [181 225 234]
#   [181 225 236]]
#
#  ...
#
#  [[ 51 122 152]
#   [ 51 122 152]
#   [ 49 120 152]
#   ...
#   [166 225 239]
#   [161 221 232]
#   [163 223 234]]
#
#  [[ 55 126 156]
#   [ 54 125 155]
#   [ 53 124 156]
#   ...
#   [165 225 236]
#   [167 227 238]
#   [169 229 240]]
#
#  [[ 58 129 159]
#   [ 58 129 159]
#   [ 56 127 159]
#   ...
#   [164 224 235]
#   [172 232 243]
#   [174 234 245]]]

# %%
imgplot = plt.imshow(img)

# %%
cropped = img[400:1280 , 300:954]

# %%
plt.imshow(cropped)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
img1 = mpimg.imread('1.jfif')

# %%
img2 = mpimg.imread('2.jfif')

# %%
imgplot1 = plt.imshow(img1)

# %%
imgplot2 = plt.imshow(img2)

# %%
img1.ndim
# Out:
# 3

# %%
cropped1 = img1[0:100,0:300]

# %%
cropped2 = img2[0:100,0:300]

# %%
plt.imshow(cropped1)

# %%
plt.imshow(cropped2)

# %%
horizontalStack = np.concatenate((cropped1, cropped2), axis=1)

# %%
plt.imshow(horizontalStack)
